-- %%
SELECT 
Edition,
Athlete,
NOC,
MedalValue,
MedalistID
FROM [test1].[dbo].[Medalist2]
WHERE Edition > (
    SELECT Edition
    FROM [test1].[dbo].[Medalist2]
    WHERE
    MedalistID = '32600'
) 
-- to find all Editions bigger than (MedalistID = 32600)'s Edition
-- Out:
-- (187 rows affected)
-- Total execution time: 00:00:00.028
-- ...
